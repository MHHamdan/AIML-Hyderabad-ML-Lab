# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint
# ### Not For Grading

# %% [markdown]
# ## Setup Steps

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2100121" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "5142192291" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook= "U1W2_04_Scipy_Exercises" #name of the notebook
Answer = "Ungraded"
def setup():
#  ipython.magic("sx pip3 install torch") 
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      print("Your submission is successful.")
      print("Ref Id:", submission_id)
      print("Date of submission: ", r["date"])
      print("Time of submission: ", r["time"])
      print("View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions")
     # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if not Additional: 
      raise NameError
    else:
      return Additional  
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError 
    else: 
      return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2100121&recordId=2028"></script>
# Setup completed successfully

# %% [markdown]
# ### Q1. Writing the image into the file using imwrite
#
# hint: imageio.imwrite

# %%
from scipy import misc
import imageio
f = misc.face() #It will take raccoon face and  return rgb image  
print(f.shape)  #It will give 768 x 1024 color image.

#YOUR CODE HERE
# Out:
# (768, 1024, 3)

# %% [markdown]
# ### Plot the image using matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(f)
plt.show() # It will display color image

# %% [markdown]
# ### Q2. Load the dog image and create numpy array from an image
#
# hint:
# 1. Load the dog image using imread  (take random dog image from internet)
# 2. Convert the dog image to gray scale using rgb2gray
# 3. Create numpy array of dog image by using np.array

# %%
from scipy import misc
dog=imageio.imread('/content/dog.jpg')
print(type(dog))
print(dog.shape)

plt.imshow(dog)
# Out:
# <class 'imageio.core.util.Array'>
# (4032, 1960, 3)

# %%
red=dog[:,:,0]
blue=dog[:,:,1]
green=dog[:,:,2]
grey = (0.2126 * red) + (0.7152 * green) + (0.0722 * blue)
plt.imshow(grey)

# %%
import numpy as np
dog_array = np.array(dog)
print(dog_array.shape)
# Out:
# (4032, 1960, 3)

# %%
from skimage.color import rgb2gray
# YOUR CODE HERE

# %% [markdown]
# ###  Q3. Get min and max value of dog image
#
# hint: max() and min()

# %%
# YOUR CODE HERE
print(dog_array.min())
print(dog_array.max())
# Out:
# 0
# 255

# %% [markdown]
# ### Q4. Get mean of the dog image
#
# hint: mean()

# %%
# YOUR CODE HERE
print(dog_array.mean())
# Out:
# 108.32138850083685

# %% [markdown]
# ### Q5. Take a list of 10 random numbers and calculate the geometric mean and harmonic mean.

# %%
import random
my_randoms = random.sample(range(100), 10)
print(my_randoms)
# Out:
# [78, 60, 41, 80, 42, 11, 73, 57, 62, 74]

# %% [markdown]
# #### Geometric mean
#
# hint: gmean

# %%
from scipy.stats import gmean
# YOUR CODE HERE
print(gmean(my_randoms))
# Out:
# 51.66046128415373

# %% [markdown]
# #### Harmonic Mean
#
# hint: hmean

# %%
from scipy.stats import hmean
# YOUR CODE HERE
print(hmean(my_randoms))
# Out:
# 41.32554603756334

# %% [markdown]
# ### Q6. Solve The below equations using scipy solver
# 4X-5Y+8Z= 4,
#
# 2X-8Y+7Z=0,
#
# -5X+8Y=-5
#
# hint: linalg.solve

# %%
from scipy import linalg
# YOUR CODE HERE
a = np.array([[4, -5, 8], [2, -8, 7], [-5, 8, 0]])
b = np.array([4, 0, -5])

# %%
x = linalg.solve(a, b)

# %%
x
# Out:
# array([ 1.53112033,  0.33195021, -0.05809129])
