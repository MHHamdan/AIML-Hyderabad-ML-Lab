# %%
letters= "lsdkjfl;asjflksjflsjf;ajflajf"

# %%
import random
random.randint?

# %%
for n in range(10):
  for size in range(5):
    print(letters[random.randint(0,len(letters)- 1)], end=" ")
  print()
# Out:
# j f d k f
# k f a f j
# a f s f f
# l ; f j l
# j l s l k
# a j f l a
# j j s j k
# l j a f a
# j l j a l
# j f k l s
