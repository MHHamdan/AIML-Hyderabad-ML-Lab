# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ### Not for Grading

# %% [markdown]
# ## Learning Objective

# %% [markdown]
# At the end of the experiment, you will be able to :
#
# * extract features using Python and  Machine Learning with scikit-learn

# %% [markdown]
# ## Setup Steps

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2100121" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "5142192291" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook= "Demo_Bag_of_Words_Python_Scikit_Learn" #name of the notebook
Answer = "Ungraded"
def setup():
    ipython.magic("sx wget https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/ipl.csv")
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "feedback_experiments_input" : Comments, "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:        
        print(r["err"])
        return None   
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://aiml.iiith.talentsprint.com/notebook_submissions")
        # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if not Additional: 
      raise NameError
    else:
      return Additional  
  except NameError:
    print ("Please answer Additional Question")
    return None
def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError 
    else: 
      return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    
else:
  print ("Please complete Id and Password cells before running setup")

# %%
import numpy as np
import os, string, re
import string

# %%
allsentences = [
    'This is the first document. It quit simple ',
    'This document is the second document. It is very simple',
    'And this is the third one. It is simple too',
    'Is this the first document? Just tttrying to add varity',
]

# %%
# Extract words of a given sentence
def word_extraction(sentence):   
    
  words = re.sub("[^\w]", " ",  sentence.lower()).split()  # Split the words
  ignore = ['a', "the", "is", 'this', 'it', 'any']  # Collect Stop words
  words = [w for w in words if w not in ignore]    # Remove Stop words
  words = [word for word in words if len(word) > 2] 
  return words

# %%
# Extract words of a given sentence
def word_extraction11(sentence):   
    
  words = re.sub("[^\w]", " ",  sentence.lower()).split()  # Split the words
  print(words)
  ignore = ['a', "the", "is", 'this', 'it', 'any']  # Collect Stop words
  print(ignore)
  words = [w for w in words if w not in ignore]    # Remove Stop words
  print(words)
  words = [word for word in words] 
  print(words)
  return words

# %%
word_extraction11(sentence)

# %%
sentence1 = 'Is this the first document? mh mhm Is this the first document? mh mhm Is this the first document? mh mhm'
def word_extraction1(sentence1):
  words1 = re.sub("[^\w]", " ",  sentence1.lower()).split()  # Split the words
  ignore1 = ['a', "the", "is", 'this', 'it', 'any']  # Collect Stop words
  words1 = [w for w in words1 if w not in ignore1]    # Remove Stop words
  print(words1)
  words1 = [word for word in words1 if len(word) > 2] 
  print(words1 )
  return words1

# %%
word_extraction1(sentence1)

# %%
# Apply tokenization to all sentences
def tokenize(allsentences): # The method iterates all the sentences and adds the extracted word into an array.
  valid_words = []
  for sentence in allsentences:
    words = word_extraction(sentence)
    #print(words)
    valid_words.extend(words)
  valid_words = sorted(list(set(valid_words)))
  return valid_words

# %%
tokenize(allsentences)

# %%
def tokenize1(sentence1): 
  valid_words1 = []
  for sent in sentence1:
    words1 = word_extraction1(sent)
    print('dfdffgdsgdgs', words1)
    valid_words1.extend(words1)
  valid_words1 = sorted(list(set(valid_words1)))
  return valid_words1

# %%
#tokenize1(sentence1)

# %%
vocab = tokenize(allsentences)  # Get the vocabulary words
print(vocab, '\n\n') 
for sentence in allsentences:
      
      words = word_extraction(sentence)
      bag_vector = np.zeros(len(vocab))  # Initialize with zero
      
      # If the word is in vocab then generate the vectors based on the counter frequency of the word in that sentence.
      for i,word in enumerate(vocab):
        for w in words:
              if word == w:              
                  bag_vector[i] += 1     
              
    
      print("{0} \n{1}\n".format(sentence,np.array(bag_vector)))

# %% [markdown]
# ## Tokenizing text with scikit-learn
#
# The scikit-learn library offers easy-to-use tools to perform both tokenization and feature extraction of your text data.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer='word',max_df=0.8)
X = vectorizer.fit_transform(allsentences)
print(vectorizer.get_feature_names())

print(allsentences,'\n', X.toarray())

# %% [markdown]
# ## Please answer the questions below to complete the experiment:

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Too Simple, I am wasting time" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "More examples on BoW representations such as a large file and audio representation " #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook  { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id =return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
